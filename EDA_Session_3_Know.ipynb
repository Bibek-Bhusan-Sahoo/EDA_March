# %% [markdown]
# **Import required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the visa data**

# %%
visa_df = pd.read_csv(r'C:\Users\LEGION\OneDrive\Documents\Naresh IT\Datafiles\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $head$
#
# - Top 5 rows

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# $tail$
#
# - Last 5 rows

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $shape$
#
# - Number of rows and Number of Columns

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f"The number of rows are {visa_df.shape[0]}")
print(f"The number of columns are {visa_df.shape[1]}")
# Out:
# The number of rows are 25480
# The number of columns are 12

# %% [markdown]
# $size$
#
# - rows * columns

# %%
visa_df.size
# Out:
# 305760

# %%
25480 * 12
# Out:
# 305760

# %% [markdown]
# **Columns**
#
# - Gives column Values

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# $dtypes$

# %%
visa_df.dtypes
# Object means categorical
# int, float means numerical
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - Undestanding data type is very very important
# - visa_df type is : **data frame**
# - visa_df.values is : **series**
# - Series object can convert into dictionary
# - After that we can use dictionary methods

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task**
#
# - Create categorical column list
# - Create numerical column list
#
# **idea**
#
# - convert series type to dictionary
# - iterate through loop
# - apply the conditions and get result in the list

# %%
columnTypes = dict(visa_df.dtypes)
categoricalColumn = []
numericalColumn = []
for key, value in columnTypes.items():
    if value == 'object':
        categoricalColumn.append(key)
    else:
        numericalColumn.append(key)
        
print(f"Categorical Columns : {categoricalColumn}", f"Numerical Column : {numericalColumn}", sep="\n")
# Out:
# Categorical Columns : ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# Numerical Column : ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **Using list comprehension**

# %%
columnTypes = dict(visa_df.dtypes)
categoricalCols = [key for key, value in columnTypes.items() if value in ['object']]
numericalCols  = [key for key, value in columnTypes.items() if value not in ['object']]
print(f"Categorical Columns : {categoricalCols}", f"Numerical Column : {numericalCols}", sep="\n")
# Out:
# Categorical Columns : ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# Numerical Column : ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# $select$-$data$-$types$
#
# - select data type will give a data frame of desired data types
# - the result is also a data frame
# - all above options like head, tail, column  apply to result

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# $is$-$null$
#
# - is used to identify any missing values are available
# - It will give True or False
# - True: yes value is missed
# - False: No value is missed

# %% [markdown]
# **Note**
#
# - if we see bound method means add the brackets

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# **sum()**
#
# - Gives number of null values in dataset

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $drop$-$duplicates$
#
# - if any duplicate rows are there, it will drop it

# %%
visa_df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **all()**
#
# -Gives True is no duplicates are present in columns

# %%
visa_df.drop_duplicates().all()
# Out:
# case_id                  True
# continent                True
# education_of_employee    True
# has_job_experience       True
# requires_job_training    True
# no_of_employees          True
# yr_of_estab              True
# region_of_employment     True
# prevailing_wage          True
# unit_of_wage             True
# full_time_position       True
# case_status              True
# dtype: bool

# %% [markdown]
# **info**
#
# - gives info about dataset

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
#
# - It is used to extract the particular index of data
# - take has one parameter called axis
# - axis = 1 means columns
# - axis = 0 means rows
# - by default axis = 0 is there
# - in below example we given 100, 200, 300 and we didn't provide axis values
# - it means we are extracting rows

# %%
visa_df.take([100, 200, 300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100, 200, 300], axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 visa_df.take([100, 200, 300], axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3871, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3862     warnings.warn(
#    3863         "is_copy is deprecated and will be removed in a future version. "
#    3864         "'take' always returns a copy, so there is no need to specify this.",
#    3865         FutureWarning,
#    3866         stacklevel=find_stack_level(),
#    3867     )
#    3869 nv.validate_take((), kwargs)
# -> 3871 return self._take(indices, axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3886, in NDFrame._take(self, indices, axis, convert_indices)
#    3879 """
#    3880 Internal version of the `take` allowing specification of additional args.
#    3881
# ...

# %%
visa_df.take(range(10, 20))

# Extract rows from index 10 till 19
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 10  EZYV11      Asia              Master's                  N
# 11  EZYV12      Asia           High School                  Y
# 12  EZYV13      Asia            Bachelor's                  Y
# 13  EZYV14      Asia            Bachelor's                  Y
# 14  EZYV15      Asia              Master's                  Y
# 15  EZYV16      Asia           High School                  Y
# 16  EZYV17    Europe              Master's                  Y
# 17  EZYV18      Asia              Master's                  Y
# 18  EZYV19    Africa              Master's                  Y
# 19  EZYV20      Asia             Doctorate                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 10                     N             2465         2004              Midwest
# 11                     N             4069         2005            Northeast
# ...

# %%
visa_df.take([2, 5, 7], axis=1)
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take(range(2, 5), axis=1)
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100:105]) # Not working
# Out:
#   Cell In[32], line 1
#     visa_df.take([100:105]) # Not working
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# -  I want 100,200,300 rows and 2,5,7 column in a single take() call
# - with single syntax it is not possible by using **take()**

# %%
visa_df.take([100, 200, 300]).take([2,5,7], axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# $iloc$
#
# - to avoid limitations of take we can use iloc

# %%
#visa_df.iloc[<[rows]>, <[columns]>]
#visa_df.iloc[<start:end>, <start:end>]

# %%
visa_df.iloc[[100, 200, 300], [2, 5, 7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[[100, 200, 300]] # returns 100,200,300 rows with all columns, same as take()
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[100:105, 2:5]
# Out:
#     education_of_employee has_job_experience requires_job_training
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N

# %%
visa_df.iloc[100:105, 2] # without column name
# Out:
# 100      Master's
# 101      Master's
# 102    Bachelor's
# 103     Doctorate
# 104      Master's
# Name: education_of_employee, dtype: object

# %%
visa_df.iloc[100:105, [2]] # with column names
# Out:
#     education_of_employee
# 100              Master's
# 101              Master's
# 102            Bachelor's
# 103             Doctorate
# 104              Master's

# %%
visa_df.iloc[[100], :] # one row all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[100, :] # one row all column but data is a series
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
type(visa_df.iloc[100, :]) # one row all column but data is a series
# Out:
# pandas.core.series.Series

# %%
visa_df.iloc[:, [2]] # all rows one column
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Note**
#
# - no bracket Series
# - with square bracket data frame

# %%
# get all rows from No of employees column
visa_df.iloc[:, [5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols = list(visa_df.columns)
cols.index("no_of_employees")
# Out:
# 5

# %% [markdown]
# $loc$
#
# - can use directly column names instead of index

# %%
visa_df.loc[[100, 200, 300], ["no_of_employees"]]
# Out:
#      no_of_employees
# 100             2227
# 200             3282
# 300             3268

# %%
visa_df.loc[[100, 200, 300], ["continent", "no_of_employees"]]
# Out:
#     continent  no_of_employees
# 100      Asia             2227
# 200      Asia             3282
# 300      Asia             3268
